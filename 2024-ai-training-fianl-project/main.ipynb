# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1MGS2BZMzd_FtW4xPv4IHg9sXL_W38UR3' -O Set5.zip
# !unzip -o Set5.zip
# Out:
# --2024-08-21 14:13:53--  https://docs.google.com/uc?export=download&id=1MGS2BZMzd_FtW4xPv4IHg9sXL_W38UR3
# Resolving docs.google.com (docs.google.com)... 142.251.42.238, 2404:6800:4012:4::200e
# Connecting to docs.google.com (docs.google.com)|142.251.42.238|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1MGS2BZMzd_FtW4xPv4IHg9sXL_W38UR3&export=download [following]
# --2024-08-21 14:13:53--  https://drive.usercontent.google.com/download?id=1MGS2BZMzd_FtW4xPv4IHg9sXL_W38UR3&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.163.33, 2404:6800:4012:4::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.163.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 972966 (950K) [application/octet-stream]
# Saving to: ‘Set5.zip’
#
# Set5.zip            100%[===================>] 950.16K  --.-KB/s    in 0.04s
#
# 2024-08-21 14:13:56 (21.8 MB/s) - ‘Set5.zip’ saved [972966/972966]
#
# Archive:  Set5.zip
#    creating: Set5/LRbicx3/
#   inflating: Set5/LRbicx3/baby.png
#   inflating: Set5/LRbicx3/bird.png
#   inflating: Set5/LRbicx3/butterfly.png
#  extracting: Set5/LRbicx3/head.png
#   inflating: Set5/LRbicx3/woman.png
#    creating: Set5/original/
#   inflating: Set5/original/baby.png
#   inflating: Set5/original/bird.png
#   inflating: Set5/original/butterfly.png
#   inflating: Set5/original/head.png
#   inflating: Set5/original/woman.png

# %%
# !pip install -r requirements.txt
# !pip install thop
# Out:
# Requirement already satisfied: thop in /home/va8800/anaconda3/lib/python3.12/site-packages (0.1.1.post2209072238)
# Requirement already satisfied: torch in /home/va8800/anaconda3/lib/python3.12/site-packages (from thop) (2.4.0)
# Requirement already satisfied: filelock in /home/va8800/anaconda3/lib/python3.12/site-packages (from torch->thop) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/va8800/anaconda3/lib/python3.12/site-packages (from torch->thop) (4.11.0)
# Requirement already satisfied: sympy in /home/va8800/anaconda3/lib/python3.12/site-packages (from torch->thop) (1.12)
# Requirement already satisfied: networkx in /home/va8800/anaconda3/lib/python3.12/site-packages (from torch->thop) (3.3)
# Requirement already satisfied: jinja2 in /home/va8800/anaconda3/lib/python3.12/site-packages (from torch->thop) (3.1.4)
# Requirement already satisfied: fsspec in /home/va8800/anaconda3/lib/python3.12/site-packages (from torch->thop) (2024.3.1)
# Requirement already satisfied: setuptools in /home/va8800/anaconda3/lib/python3.12/site-packages (from torch->thop) (69.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/va8800/anaconda3/lib/python3.12/site-packages (from jinja2->torch->thop) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/va8800/anaconda3/lib/python3.12/site-packages (from sympy->torch->thop) (1.3.0)

# %%
# !python3 demo.py
# Out:
# /home/va8800/ken_ai/2024-ai-training-fianl-project/demo.py:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('model.pth', map_location=device)
# Traceback (most recent call last):
#   File "/home/va8800/ken_ai/2024-ai-training-fianl-project/demo.py", line 126, in <module>
#     state_dict = torch.load('model.pth', map_location=device)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/va8800/anaconda3/lib/python3.12/site-packages/torch/serialization.py", line 1065, in load
#     with _open_file_like(f, 'rb') as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/va8800/anaconda3/lib/python3.12/site-packages/torch/serialization.py", line 468, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/va8800/anaconda3/lib/python3.12/site-packages/torch/serialization.py", line 449, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'model.pth'
